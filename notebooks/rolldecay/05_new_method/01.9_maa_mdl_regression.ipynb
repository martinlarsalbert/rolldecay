# %% [markdown]
# # Roll damping regression
# Development of an empirical regression method to predict roll damping

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option("display.max_columns", None)
import numpy as np
import os
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5

import data
import copy
from mdldb.mdl_db import MDLDataBase
from mdldb.tables import Base, Model, LoadingCondition, Run, RolldecayLinear, RolldecayDirect, RolldecayNorwegian
from mdldb.tables import Min, Mean, Max, Std, Ship
from mdldb import mdl_to_evaluation
from evaluation.run_dynamic import RunDynamic
from evaluation.run_manoeuvring import RunZigZag
from rolldecay.bis_system import BisSystem

from rolldecayestimators.direct_estimator import DirectEstimator
from rolldecayestimators.direct_linear_estimator import DirectLinearEstimator
from rolldecayestimators.norwegian_estimator import NorwegianEstimator
from rolldecayestimators.transformers import CutTransformer, LowpassFilterDerivatorTransformer, ScaleFactorTransformer, OffsetTransformer
#from rolldecay.equations_lambdify import calculate_acceleration, calculate_velocity
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline

import signal_lab
from sqlalchemy.inspection import inspect
import seaborn as sns
import docs
# Out:
# c:\dev\rolldecay\venv\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///' + data.mdl_db_path)
db = MDLDataBase(engine=engine)

# %%
sql="""
SELECT * from
rolldecay_direct_improved
INNER JOIN run
ON rolldecay_direct_improved.run_id == run.id
    INNER JOIN loading_conditions
    ON (run.loading_condition_id == loading_conditions.id)
        INNER JOIN models
        ON run.model_number == models.model_number
            INNER JOIN ships
            ON models.ship_name == ships.name

"""
df_rolldecay = pd.read_sql(sql, con=engine, index_col='run_id',)
df_rolldecay = df_rolldecay.loc[:,~df_rolldecay.columns.duplicated()]
#df_rolldecay = remove_outliers(df_rolldecay)
df_rolldecay.describe()
# Out:
#                 d  mean_damping      omega0         dGM       score  \
# count  380.000000    380.000000  380.000000  380.000000  380.000000
# mean     0.322593      0.033261    0.421935    0.170331    0.970729
# std      0.253927      0.028216    0.110434    0.683945    0.124244
# min     -0.962442     -0.011579    0.132603   -1.488876   -0.969359
# 25%      0.201286      0.013011    0.338464   -0.002732    0.993563
# 50%      0.309068      0.025751    0.418260    0.080250    0.997090
# 75%      0.424527      0.043020    0.485423    0.165676    0.998551
# max      2.751673      0.158847    0.732458    4.706217    0.999798
#
#              zeta            id  project_number  series_number  run_number  \
# count  380.000000    380.000000    3.800000e+02     380.000000  380.000000
# mean     0.027542  11897.750000    2.117855e+07      13.039474   22.163158
# std      0.028496   6072.673073    3.834227e+06      27.509960   14.129992
# min     -0.026018     59.000000    2.005384e+07       0.000000    1.000000
# 25%      0.007388   7436.250000    2.011331e+07       1.000000   11.000000
# 50%      0.018473  11564.000000    2.013150e+07       5.000000   21.000000
# 75%      0.037620  17313.500000    2.015749e+07      11.000000   29.000000
# max      0.175938  21201.000000    4.010545e+07     221.000000  113.000000
#
#        test_number  loading_condition_id  ship_speed         lcg          kg  \
# count        380.0            380.000000  380.000000  380.000000  380.000000
# mean           1.0             91.955263    7.815342    2.623015   12.815918
# std            0.0             45.017330    8.025969   17.205133    4.527627
# min            1.0              1.000000    0.000000  -12.570000    0.000000
# 25%            1.0             61.750000    0.000000   -2.290000    9.397500
#               BKB        PROT           D       LSKEG          RR       XSKEG  \
# count  262.000000  178.000000  271.000000  184.000000  184.000000  184.000000
# mean     0.356469    2.258427    6.977657   29.085870    2.517576 -109.439130
# std      0.184977    0.968756    2.029327    7.465829    0.994305   26.272631
# min      0.000000    1.000000    2.200000   13.500000    2.320000 -151.000000
# 25%      0.300000    1.000000    5.750000   25.000000    2.320000 -124.000000
# 50%      0.400000    3.000000    7.800000   28.000000    2.320000 -122.000000
# 75%      0.440000    3.000000    8.300000   34.000000    2.320000  -94.500000
# max      1.050000    3.000000   10.200000   49.000000   10.000000  -26.500000
#
#              NDES          AR     BR    BRA        IRUD       PTYPE  \
# count  223.000000  271.000000  184.0  184.0  271.000000  271.000000
# mean    92.700897   51.826863    0.0    0.0    1.605166    1.044280
# std     37.326839   33.411414    0.0    0.0    0.511906    0.419297
# min     65.100000    0.000000    0.0    0.0    0.000000    1.000000
# 25%     73.000000   34.055000    0.0    0.0    1.000000    1.000000
# 50%     78.500000   49.400000    0.0    0.0    2.000000    1.000000
# 75%     97.200000   65.280000    0.0    0.0    2.000000    1.000000
# max    286.800000  157.750000    0.0    0.0    2.000000    5.000000
#
#              XRUD       HSKEG       RSKEG         LOA  ship_type_id
# count  184.000000  184.000000  184.000000  271.000000    214.000000
# mean  -126.746821    7.856359   19.685870  245.297491      4.257009
# std     30.626246    1.398999   15.357176   74.307442      2.531366
# min   -172.800000    2.900000    0.000000   50.200000      1.000000
# 25%   -143.150000    7.300000    8.400000  190.900000      4.000000
# 50%   -139.500000    7.800000   13.500000  290.000000      4.000000
# 75%   -109.180000    8.300000   28.000000  293.900000      4.000000
# max      0.000000   11.200000   58.000000  361.000000     11.000000

# %%
df_rolldecay.columns
# Out:
# Index(['d', 'mean_damping', 'omega0', 'dGM', 'score', 'zeta', 'id',
#        'project_number', 'series_number', 'run_number', 'test_number',
#        'model_number', 'ship_name', 'loading_condition_id', 'ascii_name',
#        'ship_speed', 'comment', 'file_path_ascii', 'file_path_log',
#        'file_path_hdf5', 'date', 'test_type', 'facility', 'angle1', 'angle2',
#        'name', 'lcg', 'kg', 'gm', 'CW', 'TF', 'TA', 'BWL', 'KXX', 'KZZ',
#        'BTT1', 'CP', 'Volume', 'A0', 'RH', 'scale_factor', 'lpp', 'beam',
#        'ABULB', 'BKX', 'TWIN', 'DCLR', 'VDES', 'RHBL', 'ASKEG', 'PD', 'ARH',
#        'CFP', 'AIX', 'PDTDES', 'RTYPE', 'SFP', 'BKL', 'BKB', 'PROT', 'D',
#        'LSKEG', 'RR', 'XSKEG', 'NDES', 'AR', 'BR', 'BRA', 'IRUD', 'PTYPE',
#        'XRUD', 'AI', 'HSKEG', 'RSKEG', 'LOA', 'ship_type_id'],
#       dtype='object')

# %%
df_rolldecay.describe()
# Out:
#                 d  mean_damping      omega0         dGM       score  \
# count  380.000000    380.000000  380.000000  380.000000  380.000000
# mean     0.322593      0.033261    0.421935    0.170331    0.970729
# Out:
# SFP                     380
# file_path_hdf5          380
# AIX                     380
# angle2                  380
# angle1                  380
# CFP                     380
# AI                      380
# PROT                    202
# BTT1                    202
# ARH                     201
# XRUD                    196
# BRA                     196
# BR                      196
# HSKEG                   196
# RSKEG                   196
# XSKEG                   196
# RR                      196
# LSKEG                   196
# ABULB                   196
# DCLR                    196
# RHBL                    196
# ASKEG                   196
# ship_type_id            166
# NDES                    157
# PDTDES                  139
# CW                      129
# CP                      129
# PD                      126
# A0                      122
# VDES                    121
# BKB                     118
# BWL                     117
# KXX                     117
# KZZ                     117
# RH                      117
# BKL                     115
# BKX                     115
# LOA                     109
# TWIN                    109
# AR                      109
# RTYPE                   109
# PTYPE                   109
# D                       109
# IRUD                    109
# lpp                      15
# omega0                    0
# loading_condition_id      0
# ship_name                 0
# model_number              0
# test_number               0
# run_number                0
# project_number            0
# series_number             0
# id                        0
# zeta                      0
# score                     0
# dGM                       0
# ship_speed                0
# mean_damping              0
# ascii_name                0
# Volume                    0
# comment                   0
# file_path_ascii           0
# file_path_log             0
# date                      0
# test_type                 0
# facility                  0
# name                      0
# lcg                       0
# kg                        0
# gm                        0
# TF                        0
# TA                        0
# scale_factor              0
# beam                      0
# d                         0
# dtype: int64

# %%
description = pd.read_sql_table('description', con=db.engine, index_col='id')

# %%
description
# Out:
#                                                     description       unit
# id
# A0                                     Midship area coefficient          -
# ABULB                Lateral projected bulbous bow area forw FP         m2
# AD                                                      Advance          m
# AI                                             Outlet area (wj)         m2
# AIX                            x-choord of intake (wj) rel. L/2          m
# AR                                Total rudder area, (1 rudder)         m2
# ARH                                       Horn area, (1 rudder)         m2
# ASKEG                longitudinal position where skeg leaves BL         m2
# beam                                               Maximum beam          m
# BKB                                          Bilge keel breadth          m
# BKL                                           Bilge keel length          m
# BKX           Distance L/2 to center of bilge keels (neg. Af...          m
# BR                               Bottom rise of section 10 (20)    degrees
# BRA                                  Bottom rise section 2 (20)    degrees
# BTT1                      Waterline beam / draft section 1 (20)          -
# BWL                                          Maximum beam in wl          m
# CFP                                         Choord of fin (pod)          m
# CP                                        Prismatic coefficient          -
# CW                                   Waterline area coefficient          -
# D                                            Propeller diameter          m
# DCLR                              Lateral distance rudder to CL          m
# Volume                                             Displacement         m3
# Dss                                       Steady state diameter          m
# gm                                    Radius of gyration – roll          m
# HSKEG                           Height of skeg at trailing edge          m
# IRUD                                          Number of rudders          -
# kg                                            Metacenter height          m
# KXX                                  Radius of gyration – pitch          m
# KZZ                                    Radius of gyration – yaw          m
# lcg           LCG rel L/2, pos fwd VCG rel base line, pos up...          m
# LOA                                             Length over all          m
# LOAD                              Design load=1, Ballast load=0          -
# lpp                                        Perpendicular length          m
# LSKEG                          Total lateral proj. area av skeg          m
# NDES                             Propeller rate at design speed        rpm
# PD                             Propeller pitch at 0.7R (design)          -
# PDTDES                          Delivered power at design speed         kW
# PROT          Direction of rotation 1:Right-handed single pr...          -
# PTYPE         1: Fix, 2: CP, 3: Pod, 4: WJ, 5: Azimuth, 6: V...          -
# RH                                       Rudder height at stock          m
# RHBL                  Vertical distance upper edge rudder to BL          m
# RR                                           Rudder/pod/wj rate  degrees/s
# RSKEG                     Sectional base line radius of skeg at          m
# RTYPE         Type of rudder 1: Conventional, 2: Schilling, ...          -
# SBLB                                   Stern bulb (0=no, 1=yes)          -
# SFP                                  Height (span) of fin (pod)          m
# TA                                                   Draft, aft          m
# TD                                            Tactical diameter          m
# TF                                                   Draft. Fwd          m
# TWIN                                               Twinskeg 0/1          -
# ship_type     1: Tanker/Bulk, 2: Container, 3: Pass/RoRo, 4:...          -
# VDES                                               Design speed      knots
# XRUD              Distance from L/2 to rudder (neg. aft of L/2)          m
# XSKEG         Length of skeg Distance L/2 to long. cg skeg (...          m
# alfa                           Scale factor at manoeuvring test          -
# betac                                  Steady state drift angle    degrees
# delc                                               Rudder angle    degrees
# dtrim                          Dynamic trim (Ta-Tf), 1:st value          m
# fic                                     Steady state heel angle    degrees
# fimax                                        Maximum heel angle    degrees
# igir                             Number of turning circle tests          -
# ires                                  Number of resistance data          -
# iz                                      Number of zig-zag tests          -
# per                                                      Period          s
# psi01                                      1:st overshoot angle    degrees
# psi02                                      2:nd overshoot angle    degrees
# psi03                                      3:rd overshoot angle    degrees
# psiz                                           Course deviation    degrees
# rc                                        Steady state yaw rate  degrees/s
# res                                       Resistance,1:st value          N
# u0                                     Initial speed, 1:st test      knots
# vc                                           Steady state speed      knots
# vres                                          speed, 2:nd value      knots
# ship_type_id  1: Tanker/Bulk, 2: Container, 3: Pass/RoRo, 4:...          -
# ship_speed                                           Ship speed       knot
# zeta                                        Linear roll damping          -
# d                                        Quadratic roll damping          -
# omega0                              Ship natural roll frequency      rad/s
# mean_damping                 Mean damping over roll angle range          -

# %%
interesting=[
'A0',
'AR',
'beam',
'BKB',
'BKL',
'BKX',
'BR',
'BRA',
'BTT1',
'CP',
'CW',
'Volume',
'gm',
'HSKEG',
'ASKEG',
'IRUD',
'kg',
'KXX',
'lcg',
'lpp',
'LSKEG',
'RH',
'RHBL',
'RTYPE',
'TA',
'TF',
'TWIN',
'ship_type_id',
'ship_speed',
'zeta',
'd',
'omega0',
'mean_damping',	
]

# %%
description.loc[interesting]
# Out:
#                                                     description     unit
# id
# A0                                     Midship area coefficient        -
# AR                                Total rudder area, (1 rudder)       m2
# beam                                               Maximum beam        m
# BKB                                          Bilge keel breadth        m
# BKL                                           Bilge keel length        m
# BKX           Distance L/2 to center of bilge keels (neg. Af...        m
# BR                               Bottom rise of section 10 (20)  degrees
# BRA                                  Bottom rise section 2 (20)  degrees
# BTT1                      Waterline beam / draft section 1 (20)        -
# CP                                        Prismatic coefficient        -
# CW                                   Waterline area coefficient        -
# Volume                                             Displacement       m3
# gm                                    Radius of gyration – roll        m
# HSKEG                           Height of skeg at trailing edge        m
# ASKEG                longitudinal position where skeg leaves BL       m2
# IRUD                                          Number of rudders        -
# kg                                            Metacenter height        m
# KXX                                  Radius of gyration – pitch        m
# lcg           LCG rel L/2, pos fwd VCG rel base line, pos up...        m
# lpp                                        Perpendicular length        m
# LSKEG                          Total lateral proj. area av skeg        m
# RH                                       Rudder height at stock        m
# RHBL                  Vertical distance upper edge rudder to BL        m
# RTYPE         Type of rudder 1: Conventional, 2: Schilling, ...        -
# TA                                                   Draft, aft        m
# TF                                                   Draft. Fwd        m
# TWIN                                               Twinskeg 0/1        -
# ship_type_id  1: Tanker/Bulk, 2: Container, 3: Pass/RoRo, 4:...        -
# ship_speed                                           Ship speed     knot
# zeta                                        Linear roll damping        -
# d                                        Quadratic roll damping        -
# omega0                              Ship natural roll frequency    rad/s
# mean_damping                 Mean damping over roll angle range        -

# %%
mask = df_rolldecay[interesting].notnull().all(axis=1)
mask.sum()
# Out:
# 110

# %%
df_rolldecay[interesting].isnull().sum()
# Out:
# A0              122
# AR              109
# beam              0
# BKB             118
# BKL             115
# BKX             115
# BR              196
# BRA             196
# BTT1            202
# CP              129
# CW              129
# Volume            0
# gm                0
# HSKEG           196
# ASKEG           196
# IRUD            109
# kg                0
# KXX             117
# lcg               0
# lpp              15
# LSKEG           196
# RH              117
# RHBL            196
# RTYPE           109
# TA                0
# TF                0
# TWIN            109
# ship_type_id    166
# ship_speed        0
# zeta              0
# d                 0
# omega0            0
# mean_damping      0
# dtype: int64

# %%
remove = ['BTT1','BR','BRA','HSKEG','ASKEG','LSKEG','RHBL','RTYPE','lcg','BKX','zeta','d','omega0','mean_damping']
add = ['ship_speed',]
important = list(set(interesting) - set(remove)) + add

# %%
mask = df_rolldecay[important].notnull().all(axis=1)
mask.sum()
# Out:
# 189

# %%
df_rolldecay[important].isnull().sum()
# Out:
# RH              117
# kg                0
# A0              122
# ship_type_id    166
# gm                0
# beam              0
# BKL             115
# KXX             117
# TWIN            109
# IRUD            109
# BKB             118
# Volume            0
# CW              129
# lpp              15
# AR              109
# CP              129
# TF                0
# TA                0
# ship_speed        0
# ship_speed        0
# dtype: int64

# %%
df = df_rolldecay.loc[mask].copy()

# %%
df = df.dropna(subset=['omega0'])

# %%
len(df)
# Out:
# 189

# %%
mask = df['score'] > 0.95
df = df.loc[mask]

# %%
important
# Out:
# ['RH',
#  'kg',
#  'A0',
#  'ship_type_id',
#  'gm',
#  'beam',
#  'BKL',
#  'KXX',
#  'TWIN',
#  'IRUD',
#  'BKB',
#  'Volume',
#  'CW',
#  'lpp',
#  'AR',
#  'CP',
#  'TF',
#  'TA',
#  'ship_speed',
#  'ship_speed']

# %%
data = df[list(set(important) | set(['zeta','d','omega0','mean_damping',]))].copy()
units = description.loc[data.columns]['unit']
data['ship_speed']*=1.852/3.6
units['ship_speed']=r'm/s'

data['g']=9.81
data['rho']=1000
units['g']=r'm/s**2'
units['rho']=r'kg/m**3'

data['omega0_hat'] = data['omega0']*np.sqrt(data['beam']/(2*data['g']))
units['omega0_hat'] = '-'

bis_system = BisSystem(lpp=data['lpp'], volume=data['Volume'], units=units)
data = bis_system.df_to_bis(data)

# %%
df.hist('score', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14367C50>]],
#       dtype=object)

# %%
data.hist('omega0', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15600210>]],
#       dtype=object)

# %%
data.hist('omega0_hat', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x154996F0>]],
#       dtype=object)

# %%
data.hist('zeta', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1437CC30>]],
#       dtype=object)

# %%
data.hist('d', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1549E630>]],
#       dtype=object)

# %%
data.hist('mean_damping', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15583FD0>]],
#       dtype=object)

# %%
X=data.drop(columns=['zeta','d','omega0','mean_damping'])

# %%
variance_treshold = VarianceThreshold(0.001)
X_ = variance_treshold.fit_transform(X)

# %%
X.shape
# Out:
# (178, 23)

# %%
X_.shape
# Out:
# (178, 10)

# %%
X_ = variance_treshold.fit_transform(X)
X_.shape
# Out:
# (178, 10)

# %%
X.columns[variance_treshold.get_support()]
# Out:
# Index(['BKL', 'IRUD', 'CP', 'TWIN', 'A0', 'ship_type_id', 'CW', 'ship_speed',
#        'rho', 'omega0_hat'],
#       dtype='object')

# %%
GM = data['gm']
rxx = data['KXX']
kxx = rxx/data['beam']
rho = data['rho']
m = rho*data['Volume']
Ixx = m*rxx**2
data['Ixx']=Ixx
if not 'Ixx' in important:
    important.append('Ixx')
g = data['g']
omega0 = data['omega0']
data['Ixx_tot'] = Ixx_tot = GM*g*m/(omega0**2)
data['Ixx_added'] = Ixx_added = Ixx_tot - Ixx

# %%
mask = data['Ixx_added']>0
data = data.loc[mask].copy()

# %% [markdown]
# ## Omega0 regression

# %%
y_key = 'omega0_hat'

fig,ax=plt.subplots()
data[y_key].hist(bins=50, ax=ax)
ax.set_title('Historgram: %s' % y_key)
# Out:
# Text(0.5, 1.0, 'Historgram: omega0_hat')

# %%
ks = np.arange(1,10)
degrees = np.arange(1,3)
results = pd.DataFrame()

variance_treshold = VarianceThreshold(0.0001)
standard_scaler = StandardScaler()

y = data[y_key]
X = data[important]

for k in ks:
    for degree in degrees:
        select_k_best = SelectKBest(k=k, score_func=f_regression)
        
       
        polynomial_features = PolynomialFeatures(degree=degree)
        linear_regression = LinearRegression()
        
        steps=[
            ('polynomial_feature', polynomial_features),
            ('standard_scaler', standard_scaler),
            ('variance_treshold',variance_treshold),
            ('select_k_best',select_k_best),
            ('linear_regression', linear_regression)
        ]
        
        model = Pipeline(steps=steps)
        score = cross_val_score(estimator=model,X=X,y=y,cv=5).mean()
        s = pd.Series()
        s['k'] = k
        s['degree'] = degree
        s['score'] = score
        results = results.append(s, ignore_index=True)

# %%
results.sort_values(by='score', ascending=False, inplace=True)

# %%
results.head()
# Out:
#     degree    k     score
# 17     2.0  9.0  0.901693
# 15     2.0  8.0  0.891911
# 11     2.0  6.0  0.838524
# 4      1.0  3.0  0.821605
# 2      1.0  2.0  0.819312

# %%
k = int(results.iloc[0]['k'])
degree = int(results.iloc[0]['degree'])

# %%
degree
# Out:
# 2

# %%
select_k_best = SelectKBest(k=k, score_func=f_regression)

standard_scaler = StandardScaler()
polynomial_features = PolynomialFeatures(degree=degree)
linear_regression = LinearRegression()

steps=[
    ('polynomial_feature', polynomial_features),
    ('standard_scaler', standard_scaler),
    ('variance_treshold',variance_treshold),
    ('select_k_best',select_k_best),
    ('linear_regression', linear_regression)
]

model = Pipeline(steps=steps)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
model.fit(X=X_train, y=y_train)
score = model.score(X=X_test, y=y_test)
score
# Out:
# 0.9725316901547112

# %%
fig,ax = plt.subplots()
ax.plot(y_test,model.predict(X_test),'.', alpha=0.5)
ax.set_title('Prediction of %s' % y_key)
ax.set_xlabel('test: %s' % y_key)
ax.set_ylabel('predicted: %s' % y_key)
# Out:
# Text(0, 0.5, 'predicted: omega0_hat')

# %% [markdown]
# ## damping regression

# %%
mask = data['ship_speed']==0
data_0 = data.loc[mask].copy()

# %%
y_key = 'mean_damping'

fig,ax=plt.subplots()
data_0[y_key].hist(bins=50, ax=ax)
ax.set_title('Historgram: %s' % y_key)
# Out:
# Text(0.5, 1.0, 'Historgram: mean_damping')

# %%
ks = np.arange(1,10)
degrees = np.arange(1,3)
results = pd.DataFrame()

variance_treshold = VarianceThreshold(0.0001)
standard_scaler = StandardScaler()

y = data_0[y_key]
X2 = data_0[important]

for k in ks:
    for degree in degrees:
        select_k_best = SelectKBest(k=k, score_func=f_regression)
        
       
        polynomial_features = PolynomialFeatures(degree=degree)
        linear_regression = LinearRegression()
        
        steps=[
            ('polynomial_feature', polynomial_features),
            ('standard_scaler', standard_scaler),
            ('variance_treshold',variance_treshold),
            ('select_k_best',select_k_best),
            ('linear_regression', linear_regression)
        ]
        
        model = Pipeline(steps=steps)
        score = cross_val_score(estimator=model,X=X2,y=y,cv=3).mean()
        s = pd.Series()
        s['k'] = k
        s['degree'] = degree
        s['score'] = score
        results = results.append(s, ignore_index=True)

# %%
results.sort_values(by='score', ascending=False, inplace=True)

# %%
results.head()
# Out:
#     degree    k     score
# 16     1.0  9.0 -0.037264
# 11     2.0  6.0 -0.469968
# 7      2.0  4.0 -0.566889
# 9      2.0  5.0 -0.574468
# 5      2.0  3.0 -0.604380

# %%
k = int(results.iloc[0]['k'])
degree = int(results.iloc[0]['degree'])

# %%
degree
# Out:
# 1

# %%
select_k_best = SelectKBest(k=k, score_func=f_regression)

standard_scaler = StandardScaler()
polynomial_features = PolynomialFeatures(degree=degree)
linear_regression = LinearRegression()

steps=[
    ('polynomial_feature', polynomial_features),
    ('standard_scaler', standard_scaler),
    ('variance_treshold',variance_treshold),
    ('select_k_best',select_k_best),
    ('linear_regression', linear_regression)
]

model = Pipeline(steps=steps)

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.33)
model.fit(X=X_train, y=y_train)
score = model.score(X=X_test, y=y_test)
score
# Out:
# 0.8660024157032127

# %%
fig,ax = plt.subplots()
ax.plot(y_test,model.predict(X_test),'.', alpha=0.5)
ax.set_title('Prediction of %s' % y_key)
ax.set_xlabel('test: %s' % y_key)
ax.set_ylabel('predicted: %s' % y_key)
# Out:
# Text(0, 0.5, 'predicted: mean_damping')
